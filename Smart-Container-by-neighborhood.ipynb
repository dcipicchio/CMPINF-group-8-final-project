# %%
import pandas as pd
import numpy

# %%
smart_trash = pd.read_csv("Smart-Containers.csv")

# %%
sort_trash = smart_trash.sort_values("neighborhood", inplace = True)

# %%
smart_trash.head(10)
# Out:
#      container_id  receptacle_model_id      assignment_date  \
# 58             61                   74  2017-09-19T12:22:48
# 259           289                   74  2017-09-22T15:33:41
# 80             83                   74  2017-09-19T12:22:49
# 81             84                   74  2017-09-19T12:22:49
# 40             42                   74  2017-09-19T12:22:47
# 8               9                   74  2017-09-19T12:22:46
# 26             28                   74  2017-09-19T12:22:47
# 3               4                   74  2017-09-14T13:24:40
# 111           118                   74  2017-09-19T12:22:51
# 100           103                   74  2017-09-19T12:22:50
#
#        last_updated_date    group_name           address        city  \
# 58   2019-11-05T02:05:17  1st Division     400 E Ohio St  Pittsburgh
# 259  2019-11-05T02:21:30  1st Division  10 Childrens Way  Pittsburgh
# 80   2019-11-05T02:20:30  1st Division  401 W Commons St  Pittsburgh
# ...

# %%
trash_sum = smart_trash.groupby("neighborhood").sum()

# %%
trash_sum
# Out:
#                            container_id  receptacle_model_id      zip  \
# neighborhood
# Allegheny Center                    718                  666   136908
# Allegheny West                     3249                 1110   228474
# Allentown                          6183                  888   182513
# Arlington                           747                  296    60840
# Banksville                          588                   74    15216
# Bedford Dwellings                  1504                  222    45657
# Beechview                          2378                  592   121728
# Beltzhoover                         441                  148    30420
# Bloomfield                        58689                 4514   928638
# Bluff                             19915                 2368   487008
# Brighton Heights                   4640                 1776   365088
# Brookline                          7943                 1258   258842
# ...

# %%
print(smart_trash['neighborhood'].value_counts())
counted_values = smart_trash['neighborhood'].value_counts()
# Out:
# South Side Flats             66
# East Liberty                 64
# Bloomfield                   61
# North Shore                  60
# Strip District               50
# Squirrel Hill South          47
# Central Oakland              44
# Carrick                      42
# Shadyside                    40
# Middle Hill                  34
# Homewood South               32
# Bluff                        32
# Lower Lawrenceville          29
# Central Lawrenceville        29
# East Allegheny               28
# Mount Washington             25
# Brighton Heights             24
# Crawford-Roberts             21
# Hazelwood                    19
# Squirrel Hill North          18
# Brookline                    17
# Sheraden                     16
# Marshall-Shadeland           16
# North Oakland                16
# Upper Lawrenceville          16
# Perry North                  16
# Allegheny West               15
# Troy Hill                    15
# Larimer                      14
# ...

# %%
highest_values = counted_values.iloc[0:27]
highest_values = co

# %%
lower_values = counted_values.iloc[27:53]
lower_values.plot.bar()

# %%
lowest_values = counted_values.iloc[53:78]
lowest_values.plot.bar()
